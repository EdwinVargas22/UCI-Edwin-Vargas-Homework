# %%
import matplotlib.pyplot as plt
import pandas as pd
from config import api_key
import random
import csv
import time
import requests

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'C:\Users\edwin\anaconda3\envs\PythonData\python.exe -m pip install --upgrade pip' command.

# %%
from citipy import citipy

# %%
cities = []

while len(cities)<643:

    x = (random.choice(range(-90, 90)))
    y = (random.choice(range(-180,180)))
    city = citipy.nearest_city(x,y).city_name
    
    city = city.replace(" ", "%20")
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 643

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


count = 1
sets = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    if count > 50:
        sets += 1
        count = 0
        
    print(f'Processing Record {count} of Set {sets} | {city}')
    print(f"{url}&q={city}")
    
    count += 1
    
    try:
        
        response = requests.get(f"{url}&q={city}").json()
        city_name.append(response["name"])
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
         
    except:
        print("City not found. Skipping...")
    continue
    
print(f"--------------")
print(f"Data Retrieval Complete")
print(f"--------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | usevya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=usevya
# Processing Record 2 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=mataura
# Processing Record 4 of Set 1 | porto%20velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=porto%20velho
# Processing Record 5 of Set 1 | kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kandrian
# Processing Record 6 of Set 1 | rabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=rabat
# Processing Record 7 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=codrington
# Processing Record 9 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ushuaia
# Processing Record 10 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=tiksi
# Processing Record 11 of Set 1 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=awjilah
# Processing Record 12 of Set 1 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=vostok
# Processing Record 13 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=saint-philippe
# Processing Record 14 of Set 1 | puerto%20ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=puerto%20ayora
# Processing Record 15 of Set 1 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=opuwo
# Processing Record 16 of Set 1 | santa%20eulalia%20del%20rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=santa%20eulalia%20del%20rio
# City not found. Skipping...
# Processing Record 17 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bengkulu
# Processing Record 18 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=hermanus
# Processing Record 19 of Set 1 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=tual
# Processing Record 20 of Set 1 | great%20yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=great%20yarmouth
# Processing Record 21 of Set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=havre-saint-pierre
# Processing Record 22 of Set 1 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=tura
# Processing Record 23 of Set 1 | langham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=langham
# Processing Record 24 of Set 1 | greenwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=greenwood
# Processing Record 25 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=avarua
# Processing Record 26 of Set 1 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=rikitea
# Processing Record 28 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=klaksvik
# Processing Record 29 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=yellowknife
# Processing Record 30 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=georgetown
# Processing Record 31 of Set 1 | ahumada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ahumada
# City not found. Skipping...
# Processing Record 32 of Set 1 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 1 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=yarmouth
# Processing Record 34 of Set 1 | new%20norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=new%20norfolk
# Processing Record 35 of Set 1 | wellington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=wellington
# Processing Record 36 of Set 1 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=najran
# Processing Record 37 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=padang
# Processing Record 38 of Set 1 | bitung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bitung
# Processing Record 39 of Set 1 | punta%20arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=punta%20arenas
# Processing Record 40 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=pevek
# Processing Record 41 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=geraldton
# Processing Record 42 of Set 1 | ribeira%20grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ribeira%20grande
# Processing Record 43 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=thompson
# Processing Record 44 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=hithadhoo
# Processing Record 45 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=butaritari
# Processing Record 46 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=saskylakh
# Processing Record 47 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=barrow
# Processing Record 48 of Set 1 | dubai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=dubai
# Processing Record 49 of Set 1 | belushya%20guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=belushya%20guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=matara
# Processing Record 0 of Set 2 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=lebu
# Processing Record 2 of Set 2 | wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=wuwei
# Processing Record 3 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=vaini
# Processing Record 4 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=sitka
# Processing Record 5 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ilulissat
# Processing Record 6 of Set 2 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kaitangata
# Processing Record 8 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=upernavik
# Processing Record 9 of Set 2 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kisangani
# Processing Record 10 of Set 2 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=boende
# Processing Record 11 of Set 2 | kutahya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kutahya
# Processing Record 12 of Set 2 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=sambava
# Processing Record 13 of Set 2 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=narsaq
# Processing Record 14 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=hobart
# Processing Record 15 of Set 2 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=laguna
# Processing Record 16 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bluff
# Processing Record 17 of Set 2 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kulhudhuffushi
# Processing Record 18 of Set 2 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=socorro
# Processing Record 19 of Set 2 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=acapulco
# Processing Record 20 of Set 2 | aracaju
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=aracaju
# Processing Record 21 of Set 2 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=krasnoselkup
# Processing Record 22 of Set 2 | bambous%20virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bambous%20virieux
# Processing Record 23 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=jamestown
# Processing Record 24 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bredasdorp
# Processing Record 25 of Set 2 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=alyangula
# Processing Record 26 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=torbay
# Processing Record 27 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bathsheba
# Processing Record 28 of Set 2 | janfida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=janfida
# Processing Record 29 of Set 2 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=wahiawa
# Processing Record 30 of Set 2 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=aklavik
# Processing Record 31 of Set 2 | nichinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nichinan
# Processing Record 32 of Set 2 | flin%20flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=flin%20flon
# Processing Record 33 of Set 2 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=aykhal
# Processing Record 34 of Set 2 | port%20alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=port%20alfred
# Processing Record 35 of Set 2 | port%20elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=port%20elizabeth
# Processing Record 36 of Set 2 | bacuit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bacuit
# City not found. Skipping...
# Processing Record 37 of Set 2 | nosy%20varika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nosy%20varika
# Processing Record 38 of Set 2 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nishihara
# Processing Record 39 of Set 2 | bur%20gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bur%20gabo
# City not found. Skipping...
# Processing Record 40 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=cidreira
# Processing Record 41 of Set 2 | cabo%20san%20lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=cabo%20san%20lucas
# Processing Record 42 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=albany
# Processing Record 43 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=busselton
# Processing Record 44 of Set 2 | nampula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nampula
# Processing Record 45 of Set 2 | nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nsanje
# Processing Record 46 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=hofn
# Processing Record 47 of Set 2 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=atar
# Processing Record 48 of Set 2 | mwandiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=mwandiga
# Processing Record 49 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=severo-kurilsk
# Processing Record 50 of Set 2 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=inuvik
# Processing Record 0 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=tuktoyaktuk
# Processing Record 1 of Set 3 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=mattru
# Processing Record 2 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=hasaki
# Processing Record 3 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=lorengau
# Processing Record 4 of Set 3 | bonito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bonito
# Processing Record 5 of Set 3 | chiriqui%20grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=chiriqui%20grande
# Processing Record 6 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=college
# Processing Record 7 of Set 3 | laurel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=laurel
# Processing Record 8 of Set 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kavieng
# Processing Record 10 of Set 3 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=myitkyina
# Processing Record 12 of Set 3 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=itarema
# Processing Record 13 of Set 3 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ahipara
# Processing Record 14 of Set 3 | cape%20town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=cape%20town
# Processing Record 15 of Set 3 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=chuy
# Processing Record 16 of Set 3 | ulundi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ulundi
# Processing Record 17 of Set 3 | devavanya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=devavanya
# Processing Record 18 of Set 3 | port%20hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=port%20hardy
# Processing Record 19 of Set 3 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=roebourne
# Processing Record 20 of Set 3 | weston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=weston
# Processing Record 21 of Set 3 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=necochea
# Processing Record 22 of Set 3 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=axim
# Processing Record 23 of Set 3 | bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=bend
# Processing Record 24 of Set 3 | south%20valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=south%20valley
# Processing Record 25 of Set 3 | nong%20khai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=nong%20khai
# Processing Record 26 of Set 3 | balimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=balimo
# City not found. Skipping...
# Processing Record 27 of Set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=vardo
# Processing Record 28 of Set 3 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=constantine
# Processing Record 29 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=atuona
# Processing Record 30 of Set 3 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=yenagoa
# Processing Record 31 of Set 3 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=meulaboh
# Processing Record 32 of Set 3 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=oistins
# Processing Record 33 of Set 3 | atherton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=atherton
# Processing Record 34 of Set 3 | east%20london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=east%20london
# Processing Record 35 of Set 3 | wukari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=wukari
# Processing Record 36 of Set 3 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kupang
# Processing Record 37 of Set 3 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=marienburg
# Processing Record 38 of Set 3 | riyaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=riyaq
# City not found. Skipping...
# Processing Record 39 of Set 3 | coari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=coari
# Processing Record 40 of Set 3 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ixtapa
# Processing Record 41 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=souillac
# Processing Record 42 of Set 3 | san%20juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=san%20juan
# Processing Record 43 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=victoria
# Processing Record 44 of Set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=ostrovnoy
# Processing Record 45 of Set 3 | mar%20del%20plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=mar%20del%20plata
# Processing Record 46 of Set 3 | phangnga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=phangnga
# Processing Record 47 of Set 3 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=houma
# Processing Record 48 of Set 3 | artyom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=artyom
# Processing Record 49 of Set 3 | quatre%20cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=quatre%20cocos
# Processing Record 50 of Set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=kavaratti
# City not found. Skipping...
# Processing Record 0 of Set 4 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=moron
# Processing Record 1 of Set 4 | sao%20joao%20da%20barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=sao%20joao%20da%20barra
# Processing Record 2 of Set 4 | shintomi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=shintomi
# Processing Record 3 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=mahebourg
# Processing Record 4 of Set 4 | pandamatenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=630d4240179e866ce779b40985486448&q=pandamatenga
