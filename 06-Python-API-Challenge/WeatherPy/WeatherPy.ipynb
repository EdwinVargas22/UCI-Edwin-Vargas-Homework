# %%
import matplotlib.pyplot as plt
import pandas as pd
from config import api_key
import random
import csv
import time
import requests
import scipy.stats as st

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'C:\Users\edwin\anaconda3\envs\PythonData\python.exe -m pip install --upgrade pip' command.

# %%
from citipy import citipy

# %%
# Create a empty list to append the cities
cities = []

# To collect a certain amount of cities
while len(cities)<643:

    # Randomly choose the cities from a certain range
    x = (random.choice(range(-90, 90)))
    y = (random.choice(range(-180,180)))
    
    # Collect the cities names nearest to the range I set up for x and y
    city = citipy.nearest_city(x,y).city_name
    
    # If the city is not in the empty cities list then to append it
    if city not in cities:
        cities.append(city)
# Count of cities        
len(cities)
# Out:
# 643

# %%
# Create url from the OpenWeather map
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
# Create emtpy list to collect the data needed to create the dataframe
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Define the count of pass through
count = 1
sets = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

# Loop through the city
for city in cities:
    
    # Setting if statement of when to create a new set and adding 1 to set
    if count > 50:
        sets += 1
        count = 0
    
    # Creating a print log of each city as it's being processed
    print(f'Processing Record %s of Set %s | %s' % (count, sets, city))
    
    # Adding 1 to count
    count += 1
    
    # Run the code
    try:
        
        # Use the requests.get and .json on the url
        response = requests.get(f"{url}&q={city}").json()
        
        # Append to the empty lists I created above
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
    # When it doesn't find a city, it will print the statement and continue searching     
    except:
        print("City not found. Skipping...")
    continue

print(f"--------------")
print(f"Data Retrieval Complete")
print(f"--------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hovd
# Processing Record 2 of Set 1 | chardara
# Processing Record 3 of Set 1 | koumac
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | ceres
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | bambanglipuro
# Processing Record 9 of Set 1 | tuatapere
# Processing Record 10 of Set 1 | coxim
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | faridan
# City not found. Skipping...
# Processing Record 13 of Set 1 | crawfordsville
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 16 of Set 1 | soe
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | mahon
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | faya
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | okha
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | aklavik
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | puqi
# Processing Record 31 of Set 1 | lumeje
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | tzucacab
# Processing Record 34 of Set 1 | waingapu
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 1 | massaguet
# Processing Record 38 of Set 1 | dunedin
# Processing Record 39 of Set 1 | opuwo
# Processing Record 40 of Set 1 | santiago del estero
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | boca do acre
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | kaihua
# Processing Record 49 of Set 1 | korla
# Processing Record 50 of Set 1 | ostrovnoy
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | muriti
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | sabzevar
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | sur
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | shimoda
# Processing Record 9 of Set 2 | whakatane
# Processing Record 10 of Set 2 | adrar
# Processing Record 11 of Set 2 | malkapur
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | weligama
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | san juan de colon
# Processing Record 16 of Set 2 | kruisfontein
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | kenai
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | kibala
# Processing Record 21 of Set 2 | saint george
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | vila velha
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | rabo de peixe
# Processing Record 30 of Set 2 | hermanus
# Processing Record 31 of Set 2 | bud
# Processing Record 32 of Set 2 | qaqortoq
# Processing Record 33 of Set 2 | nyurba
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | avera
# Processing Record 36 of Set 2 | la romana
# Processing Record 37 of Set 2 | mayo
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | qasigiannguit
# Processing Record 41 of Set 2 | bridlington
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | cape canaveral
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | zapadnaya dvina
# Processing Record 46 of Set 2 | coria
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | grindavik
# Processing Record 49 of Set 2 | ibotirama
# Processing Record 50 of Set 2 | kerchevskiy
# Processing Record 0 of Set 3 | tuktoyaktuk
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | rio grande
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | paramirim
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | kidal
# Processing Record 7 of Set 3 | buin
# Processing Record 8 of Set 3 | indi
# Processing Record 9 of Set 3 | nanortalik
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | san cristobal
# Processing Record 12 of Set 3 | ixtapa
# Processing Record 13 of Set 3 | jeremie
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | necochea
# Processing Record 18 of Set 3 | kirovsk
# Processing Record 19 of Set 3 | cockburn town
# Processing Record 20 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 3 | borogontsy
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | dubenskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | baijiantan
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | mapimi
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | najran
# Processing Record 32 of Set 3 | coatesville
# Processing Record 33 of Set 3 | susurluk
# Processing Record 34 of Set 3 | santo antonio do sudoeste
# Processing Record 35 of Set 3 | pirenopolis
# Processing Record 36 of Set 3 | padang
# Processing Record 37 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 3 | mount isa
# Processing Record 39 of Set 3 | mirandola
# Processing Record 40 of Set 3 | mnogovershinnyy
# Processing Record 41 of Set 3 | paso de los toros
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | vichuga
# Processing Record 44 of Set 3 | correntina
# Processing Record 45 of Set 3 | novoseleznevo
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | baykit
# Processing Record 49 of Set 3 | san patricio
# Processing Record 50 of Set 3 | norman wells
# Processing Record 0 of Set 4 | homer
# Processing Record 1 of Set 4 | kieta
# Processing Record 2 of Set 4 | tilichiki
# Processing Record 3 of Set 4 | whitehorse
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | saint-paul
# Processing Record 6 of Set 4 | gasa
# Processing Record 7 of Set 4 | franklin
# Processing Record 8 of Set 4 | trincomalee
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | namatanai
# Processing Record 11 of Set 4 | ayagoz
# Processing Record 12 of Set 4 | londoko
# Processing Record 13 of Set 4 | havre
# Processing Record 14 of Set 4 | kommunar
# Processing Record 15 of Set 4 | alice springs
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | sao felix do xingu
# Processing Record 19 of Set 4 | hay river
# Processing Record 20 of Set 4 | upington
# Processing Record 21 of Set 4 | kosjeric
# Processing Record 22 of Set 4 | bogovarovo
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 4 | abu dhabi
# Processing Record 27 of Set 4 | orlik
# Processing Record 28 of Set 4 | faanui
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | samarai
# Processing Record 32 of Set 4 | lavrentiya
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | shetpe
# Processing Record 35 of Set 4 | paamiut
# Processing Record 36 of Set 4 | pemangkat
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | vestmannaeyjar
# Processing Record 39 of Set 4 | yatou
# Processing Record 40 of Set 4 | hobyo
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | novyy urengoy
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 4 | bahia blanca
# Processing Record 46 of Set 4 | fare
# Processing Record 47 of Set 4 | olafsvik
# Processing Record 48 of Set 4 | kargasok
# Processing Record 49 of Set 4 | burns lake
# Processing Record 50 of Set 4 | lata
# Processing Record 0 of Set 5 | komsomolskiy
# Processing Record 1 of Set 5 | egvekinot
# Processing Record 2 of Set 5 | sabha
# Processing Record 3 of Set 5 | te anau
# Processing Record 4 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 5 | kolpashevo
# Processing Record 6 of Set 5 | eureka
# Processing Record 7 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 5 | pochutla
# Processing Record 9 of Set 5 | xai-xai
# Processing Record 10 of Set 5 | koungheul
# Processing Record 11 of Set 5 | djibo
# Processing Record 12 of Set 5 | flinders
# Processing Record 13 of Set 5 | lang suan
# Processing Record 14 of Set 5 | chulym
# Processing Record 15 of Set 5 | pennagaram
# Processing Record 16 of Set 5 | tecoanapa
# Processing Record 17 of Set 5 | lakatoro
# Processing Record 18 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 5 | bayan
# Processing Record 20 of Set 5 | entre rios
# Processing Record 21 of Set 5 | pisco
# Processing Record 22 of Set 5 | marawi
# Processing Record 23 of Set 5 | liwale
# Processing Record 24 of Set 5 | qazvin
# Processing Record 25 of Set 5 | longyan
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | huilong
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | dawlatabad
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | ahuimanu
# Processing Record 32 of Set 5 | tshikapa
# Processing Record 33 of Set 5 | praia da vitoria
# Processing Record 34 of Set 5 | port alfred
# Processing Record 35 of Set 5 | matay
# Processing Record 36 of Set 5 | canavieiras
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | walvis bay
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | fukuma
# Processing Record 41 of Set 5 | tual
# Processing Record 42 of Set 5 | uch
# Processing Record 43 of Set 5 | lafia
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | axim
# Processing Record 46 of Set 5 | lashio
# Processing Record 47 of Set 5 | taldan
# Processing Record 48 of Set 5 | anloga
# Processing Record 49 of Set 5 | gueret
# Processing Record 50 of Set 5 | okhotsk
# Processing Record 0 of Set 6 | pouso alegre
# Processing Record 1 of Set 6 | ibicui
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | zabid
# Processing Record 4 of Set 6 | waw
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | hilo
# Processing Record 7 of Set 6 | inhambane
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | mehamn
# Processing Record 10 of Set 6 | port hardy
# Processing Record 11 of Set 6 | purpe
# Processing Record 12 of Set 6 | athabasca
# Processing Record 13 of Set 6 | kupang
# Processing Record 14 of Set 6 | arraial do cabo
# Processing Record 15 of Set 6 | lamont
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | othonoi
# City not found. Skipping...
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | kaiu
# Processing Record 21 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 6 | laguna
# Processing Record 24 of Set 6 | gao
# Processing Record 25 of Set 6 | portales
# Processing Record 26 of Set 6 | beloha
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | khorramshahr
# Processing Record 29 of Set 6 | santa cruz
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | kununurra
# Processing Record 33 of Set 6 | khunti
# Processing Record 34 of Set 6 | wana
# Processing Record 35 of Set 6 | qingyuan
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | huarmey
# Processing Record 40 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | itarema
# Processing Record 43 of Set 6 | sorong
# Processing Record 44 of Set 6 | tessalit
# Processing Record 45 of Set 6 | iqaluit
# Processing Record 46 of Set 6 | kanniyakumari
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | rawson
# Processing Record 50 of Set 6 | esmeraldas
# Processing Record 0 of Set 7 | cayenne
# Processing Record 1 of Set 7 | half moon bay
# Processing Record 2 of Set 7 | uige
# Processing Record 3 of Set 7 | tripoli
# Processing Record 4 of Set 7 | ponta delgada
# Processing Record 5 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 6 of Set 7 | tateyama
# Processing Record 7 of Set 7 | san ramon
# Processing Record 8 of Set 7 | tagusao
# Processing Record 9 of Set 7 | constantine
# Processing Record 10 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 7 | pakxan
# Processing Record 12 of Set 7 | carutapera
# Processing Record 13 of Set 7 | lagos
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | sibolga
# Processing Record 16 of Set 7 | nizhniy kuranakh
# Processing Record 17 of Set 7 | saint-medard-en-jalles
# Processing Record 18 of Set 7 | carroll
# Processing Record 19 of Set 7 | atagay
# Processing Record 20 of Set 7 | kholtoson
# Processing Record 21 of Set 7 | camacha
# Processing Record 22 of Set 7 | saint anthony
# Processing Record 23 of Set 7 | ewo
# Processing Record 24 of Set 7 | vilhena
# Processing Record 25 of Set 7 | fushun
# Processing Record 26 of Set 7 | galveston
# Processing Record 27 of Set 7 | udachnyy
# Processing Record 28 of Set 7 | ndola
# Processing Record 29 of Set 7 | januaria
# Processing Record 30 of Set 7 | alekseyevka
# Processing Record 31 of Set 7 | peniche
# Processing Record 32 of Set 7 | kuznechnoye
# Processing Record 33 of Set 7 | binzhou
# Processing Record 34 of Set 7 | san angelo
# Processing Record 35 of Set 7 | port hedland
# Processing Record 36 of Set 7 | verkhnyaya inta
# Processing Record 37 of Set 7 | vostok
# Processing Record 38 of Set 7 | maningrida
# Processing Record 39 of Set 7 | serebryanyy bor
# Processing Record 40 of Set 7 | isabela
# Processing Record 41 of Set 7 | sioux lookout
# Processing Record 42 of Set 7 | gravdal
# Processing Record 43 of Set 7 | garissa
# Processing Record 44 of Set 7 | yako
# Processing Record 45 of Set 7 | beisfjord
# Processing Record 46 of Set 7 | road town
# Processing Record 47 of Set 7 | svetlogorsk
# Processing Record 48 of Set 7 | ha tinh
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | saint-pierre
# Processing Record 0 of Set 8 | asau
# Processing Record 1 of Set 8 | mahibadhoo
# Processing Record 2 of Set 8 | dicabisagan
# City not found. Skipping...
# Processing Record 3 of Set 8 | kambove
# Processing Record 4 of Set 8 | roches noires
# City not found. Skipping...
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | omboue
# Processing Record 7 of Set 8 | sheridan
# Processing Record 8 of Set 8 | nadvoitsy
# Processing Record 9 of Set 8 | pauini
# Processing Record 10 of Set 8 | stulovo
# Processing Record 11 of Set 8 | port said
# Processing Record 12 of Set 8 | port moresby
# Processing Record 13 of Set 8 | zeya
# Processing Record 14 of Set 8 | nipawin
# Processing Record 15 of Set 8 | beringovskiy
# Processing Record 16 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 8 | timizart
# Processing Record 18 of Set 8 | san policarpo
# Processing Record 19 of Set 8 | westport
# Processing Record 20 of Set 8 | clyde river
# Processing Record 21 of Set 8 | wahiawa
# Processing Record 22 of Set 8 | calama
# Processing Record 23 of Set 8 | vanavara
# Processing Record 24 of Set 8 | barrow
# Processing Record 25 of Set 8 | thunder bay
# Processing Record 26 of Set 8 | quebo
# Processing Record 27 of Set 8 | xichang
# Processing Record 28 of Set 8 | koupela
# Processing Record 29 of Set 8 | mecca
# Processing Record 30 of Set 8 | dangriga
# Processing Record 31 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 8 | uvira
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | golspie
# Processing Record 36 of Set 8 | khatanga
# Processing Record 37 of Set 8 | kocser
# Processing Record 38 of Set 8 | newport
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | bara
# Processing Record 42 of Set 8 | mastic beach
# Processing Record 43 of Set 8 | los llanos de aridane
# Processing Record 44 of Set 8 | pedernales
# Processing Record 45 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 8 | dingle
# Processing Record 47 of Set 8 | nykobing
# City not found. Skipping...
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | sajanan
# Processing Record 50 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 0 of Set 9 | winkler
# Processing Record 1 of Set 9 | konstantinovka
# Processing Record 2 of Set 9 | amalfi
# Processing Record 3 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | ingham
# Processing Record 5 of Set 9 | frontera
# Processing Record 6 of Set 9 | soyo
# Processing Record 7 of Set 9 | radcliff
# Processing Record 8 of Set 9 | jaromerice nad rokytnou
# Processing Record 9 of Set 9 | shitkino
# Processing Record 10 of Set 9 | manggar
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | kavaratti
# Processing Record 13 of Set 9 | arlit
# Processing Record 14 of Set 9 | constitucion
# Processing Record 15 of Set 9 | yusva
# City not found. Skipping...
# Processing Record 16 of Set 9 | sisimiut
# Processing Record 17 of Set 9 | zavyalovo
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | madang
# Processing Record 20 of Set 9 | nelson bay
# Processing Record 21 of Set 9 | cananeia
# Processing Record 22 of Set 9 | tabas
# Processing Record 23 of Set 9 | thinadhoo
# Processing Record 24 of Set 9 | caracuaro
# Processing Record 25 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 9 | ponta do sol
# Processing Record 27 of Set 9 | carpentras
# Processing Record 28 of Set 9 | putina
# Processing Record 29 of Set 9 | srednekolymsk
# Processing Record 30 of Set 9 | rajo khanani
# Processing Record 31 of Set 9 | mataram
# Processing Record 32 of Set 9 | brae
# Processing Record 33 of Set 9 | jertih
# Processing Record 34 of Set 9 | malanville
# Processing Record 35 of Set 9 | mongo
# Processing Record 36 of Set 9 | oistins
# Processing Record 37 of Set 9 | fort nelson
# Processing Record 38 of Set 9 | souillac
# Processing Record 39 of Set 9 | dalby
# Processing Record 40 of Set 9 | bardiyah
# Processing Record 41 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 9 | knysna
# Processing Record 43 of Set 9 | tabuk
# Processing Record 44 of Set 9 | lixourion
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | ahipara
# Processing Record 47 of Set 9 | koutsouras
# Processing Record 48 of Set 9 | impfondo
# Processing Record 49 of Set 9 | tevaitoa
# Processing Record 50 of Set 9 | yambio
# Processing Record 0 of Set 10 | port augusta
# Processing Record 1 of Set 10 | salinopolis
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 10 | chitral
# Processing Record 5 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 10 | antofagasta
# Processing Record 7 of Set 10 | saryg-sep
# Processing Record 8 of Set 10 | jati
# Processing Record 9 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 10 | kloulklubed
# Processing Record 11 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 10 | yumen
# Processing Record 13 of Set 10 | crotone
# Processing Record 14 of Set 10 | rocha
# Processing Record 15 of Set 10 | lucea
# Processing Record 16 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | bagdarin
# Processing Record 19 of Set 10 | georgetown
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | yaan
# Processing Record 22 of Set 10 | saint-denis
# Processing Record 23 of Set 10 | north bend
# Processing Record 24 of Set 10 | vanderhoof
# Processing Record 25 of Set 10 | suratgarh
# Processing Record 26 of Set 10 | bugaan
# Processing Record 27 of Set 10 | prainha
# Processing Record 28 of Set 10 | tsumeb
# Processing Record 29 of Set 10 | moree
# Processing Record 30 of Set 10 | alanya
# Processing Record 31 of Set 10 | tari
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 10 | guarapari
# Processing Record 35 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 10 | sistranda
# Processing Record 37 of Set 10 | eyl
# Processing Record 38 of Set 10 | kuruman
# Processing Record 39 of Set 10 | sagua la grande
# Processing Record 40 of Set 10 | balkhash
# Processing Record 41 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 10 | satun
# Processing Record 43 of Set 10 | guerrero negro
# Processing Record 44 of Set 10 | tefe
# Processing Record 45 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 46 of Set 10 | burica
# City not found. Skipping...
# Processing Record 47 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 10 | kuryk
# Processing Record 49 of Set 10 | martapura
# Processing Record 50 of Set 10 | broken hill
# Processing Record 0 of Set 11 | bainbridge
# Processing Record 1 of Set 11 | sherpur
# Processing Record 2 of Set 11 | wajima
# Processing Record 3 of Set 11 | saint simons
# Processing Record 4 of Set 11 | anahuac
# Processing Record 5 of Set 11 | alyangula
# Processing Record 6 of Set 11 | valladolid
# Processing Record 7 of Set 11 | savelugu
# Processing Record 8 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 11 | leshukonskoye
# Processing Record 10 of Set 11 | ponnampet
# Processing Record 11 of Set 11 | ous
# Processing Record 12 of Set 11 | cidreira
# Processing Record 13 of Set 11 | palmer
# Processing Record 14 of Set 11 | dali
# Processing Record 15 of Set 11 | mendeleyevo
# Processing Record 16 of Set 11 | belmonte
# Processing Record 17 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 11 | suntar
# Processing Record 19 of Set 11 | am timan
# Processing Record 20 of Set 11 | mutoko
# Processing Record 21 of Set 11 | caravelas
# Processing Record 22 of Set 11 | pitimbu
# Processing Record 23 of Set 11 | makhu
# Processing Record 24 of Set 11 | bull savanna
# Processing Record 25 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 11 | anisoc
# Processing Record 27 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 11 | cervo
# Processing Record 29 of Set 11 | cambara
# Processing Record 30 of Set 11 | torbay
# Processing Record 31 of Set 11 | lorengau
# Processing Record 32 of Set 11 | ibirite
# Processing Record 33 of Set 11 | hofn
# Processing Record 34 of Set 11 | cottonwood
# Processing Record 35 of Set 11 | mwinilunga
# Processing Record 36 of Set 11 | balkanabat
# Processing Record 37 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 38 of Set 11 | puerto lopez
# Processing Record 39 of Set 11 | corning
# Processing Record 40 of Set 11 | rancho palos verdes
# Processing Record 41 of Set 11 | san vicente
# Processing Record 42 of Set 11 | saint-joseph
# Processing Record 43 of Set 11 | buritis
# Processing Record 44 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 11 | pyshma
# Processing Record 46 of Set 11 | tomari
# Processing Record 47 of Set 11 | fallon
# Processing Record 48 of Set 11 | bosaso
# Processing Record 49 of Set 11 | morlaix
# Processing Record 50 of Set 11 | ocho rios
# Processing Record 0 of Set 12 | hohhot
# Processing Record 1 of Set 12 | ban tak
# Processing Record 2 of Set 12 | aksu
# Processing Record 3 of Set 12 | kirovskaya
# Processing Record 4 of Set 12 | lakes entrance
# Processing Record 5 of Set 12 | hattiesburg
# Processing Record 6 of Set 12 | stockach
# Processing Record 7 of Set 12 | la plata
# Processing Record 8 of Set 12 | abalak
# Processing Record 9 of Set 12 | yulara
# Processing Record 10 of Set 12 | tocopilla
# Processing Record 11 of Set 12 | lovozero
# Processing Record 12 of Set 12 | kassala
# Processing Record 13 of Set 12 | kahului
# Processing Record 14 of Set 12 | belyy yar
# Processing Record 15 of Set 12 | kathmandu
# Processing Record 16 of Set 12 | manitouwadge
# Processing Record 17 of Set 12 | quatre cocos
# Processing Record 18 of Set 12 | strezhevoy
# Processing Record 19 of Set 12 | sulangan
# Processing Record 20 of Set 12 | manokwari
# Processing Record 21 of Set 12 | linxia
# Processing Record 22 of Set 12 | prince albert
# Processing Record 23 of Set 12 | jalu
# Processing Record 24 of Set 12 | vila franca do campo
# Processing Record 25 of Set 12 | manakara
# Processing Record 26 of Set 12 | kemin
# Processing Record 27 of Set 12 | gumdag
# Processing Record 28 of Set 12 | sainte-rose
# Processing Record 29 of Set 12 | autun
# Processing Record 30 of Set 12 | fairbanks
# Processing Record 31 of Set 12 | port blair
# Processing Record 32 of Set 12 | inta
# Processing Record 33 of Set 12 | les herbiers
# Processing Record 34 of Set 12 | bathsheba
# Processing Record 35 of Set 12 | harmanli
# Processing Record 36 of Set 12 | aasiaat
# Processing Record 37 of Set 12 | bozdar
# Processing Record 38 of Set 12 | saldanha
# Processing Record 39 of Set 12 | canchungo
# Processing Record 40 of Set 12 | mbanza-ngungu
# Processing Record 41 of Set 12 | bandarbeyla
# Processing Record 42 of Set 12 | narsaq
# Processing Record 43 of Set 12 | yendi
# Processing Record 44 of Set 12 | peresichna
# Processing Record 45 of Set 12 | pahrump
# Processing Record 46 of Set 12 | sol-iletsk
# Processing Record 47 of Set 12 | sarangani
# Processing Record 48 of Set 12 | bhadra
# Processing Record 49 of Set 12 | west bay
# Processing Record 50 of Set 12 | crestview
# Processing Record 0 of Set 13 | yarkovo
# Processing Record 1 of Set 13 | valparaiso
# Processing Record 2 of Set 13 | sayyan
# Processing Record 3 of Set 13 | nioro
# Processing Record 4 of Set 13 | lahad datu
# Processing Record 5 of Set 13 | jumla
# Processing Record 6 of Set 13 | ankang
# Processing Record 7 of Set 13 | baruun-urt
# Processing Record 8 of Set 13 | moerai
# Processing Record 9 of Set 13 | smithers
# Processing Record 10 of Set 13 | storslett
# Processing Record 11 of Set 13 | tarakan
# Processing Record 12 of Set 13 | sinnamary
# Processing Record 13 of Set 13 | ambilobe
# Processing Record 14 of Set 13 | saint-paul-les-dax
# Processing Record 15 of Set 13 | salisbury
# Processing Record 16 of Set 13 | pandan
# Processing Record 17 of Set 13 | seoul
# Processing Record 18 of Set 13 | progreso
# Processing Record 19 of Set 13 | vanimo
# Processing Record 20 of Set 13 | alice
# Processing Record 21 of Set 13 | college
# Processing Record 22 of Set 13 | the pas
# Processing Record 23 of Set 13 | beaune
# Processing Record 24 of Set 13 | makakilo city
# Processing Record 25 of Set 13 | qostanay
# Processing Record 26 of Set 13 | san ignacio
# Processing Record 27 of Set 13 | santa isabel do rio negro
# Processing Record 28 of Set 13 | evensk
# Processing Record 29 of Set 13 | shiyan
# Processing Record 30 of Set 13 | staryy nadym
# Processing Record 31 of Set 13 | da nang
# --------------
# Data Retrieval Complete
# --------------

# %%
# Create a dictionary of the data I collected from the empty list above
weather_dictionary = {
            "City": city_name,
            "Lat": lat,
            "Lng": lng,
            "Max Temp": max_temp,
            "Humidity": humidity,
            "Cloudiness": cloudiness,
            "Wind Speed": wind_speed,
            "Country": country,
            "Date": date,
}

# Set it up as a DataFrame
weather_city_data = pd.DataFrame(weather_dictionary)

# Export the data into a .csv file
weather_city_data.to_csv('CSV Data/weather_city_data.csv',index=False)

# Use count on the DataFrame to see if the data equals to each other and how much data we have
weather_city_data.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Displayed the DataFrame
weather_city_data.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Khovd  48.01   91.64     42.60        56           0        6.89
# 1  Chardara  41.25   67.97     55.71        37           0        7.72
# 2    Koumac -20.57  164.28     78.17        56           3        8.79
# 3   Rikitea -23.12 -134.97     74.70        81         100       18.66
# 4      Chui -33.70  -53.46     62.53        86           0        6.55
#
#   Country        Date
# 0      MN  1603074775
# 1      KZ  1603074907
# 2      NC  1603074907
# 3      PF  1603074908
# 4      UY  1603074908

# %%
# Removed any Humidity value that is greater than 100
indexNames = weather_city_data[weather_city_data['Humidity'] > 100].index

weather_city_data.drop(indexNames, inplace = True)

# Checked if any data was removed
weather_city_data.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Latitude vs Temperature Plot
# Plot the scatter plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Max Temp'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saved the scatter plot as a png image
plt.savefig("Latitude vs. Temperature Plot.png")
plt.show()
print("The scatter plot is analyzing if there is a correlation between city latitude and max temperature. As the latitude goes from negative to 0 near the equator, the temperature increases then after the equator, it starts to decreases")
# Out:
# The scatter plot is analyzing if there is a correlation between city latitude and max temperature. As the latitude goes from negative to 0 near the equator, the temperature increases then after the equator, it starts to decreases

# %%
# Latitude vs Humidity Plot
# Plot the scatter plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Humidity'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saved the scatter plot as a png image
plt.savefig("Latitude vs. Humidity Plot.png")
plt.show()
print("The scatter plot is analyzing if there is a correlation between city latitude and humidity. It seems there isn't a positive or negative correlation because the points are equally spread but it does seem once the latitude passes 40, humidity falls between 75% to 100%.")
# Out:
# The scatter plot is analyzing if there is a correlation between city latitude and humidity. It seems there isn't a positive or negative correlation because the points are equally spread but it does seem once the latitude passes 40, humidity falls between 75% to 100%.

# %%
# Latitude vs Cloudiness Plot
# Plot the scatter plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Cloudiness'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saved the scatter plot as a png image
plt.savefig("Latitude vs. Cloudiness Plot.png")
plt.show()
print("The scatter plot is analyzing if there is a correlation between city latitude and cloudiness. Most of the points are focused at 0% cloudiness and 100% cloudiness in any latitude so it's difficult to see if there is a positive or negative correlatoin.")
# Out:
# The scatter plot is analyzing if there is a correlation between city latitude and cloudiness. Most of the points are focused at 0% cloudiness and 100% cloudiness in any latitude so it's difficult to see if there is a positive or negative correlatoin.

# %%
# Latitude vs Wind Speed Plot
# Plot the scatter plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Wind Speed'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Saved the scatter plot as a png image
plt.savefig("Latitude vs. Wind Speed Plot.png")
plt.show()
print("The scatter plot is analyzing if there is a correlation between city latitude and wind speed. It appears the wind speed falls down between 0mph and 15mph for any latitude.")
# Out:
# The scatter plot is analyzing if there is a correlation between city latitude and wind speed. It appears the wind speed falls down between 0mph and 15mph for any latitude.

# %%
# Split the DataFrame into a Northern Hemisphere and Southern Hemisphere
northern_hemisphere = weather_city_data.loc[weather_city_data["Lat"] >= 0]
southern_hemisphere = weather_city_data.loc[weather_city_data["Lat"] < 0]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression  
# Set up the linear regression
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(0, 100)
plt.xlim(0, 80)

plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
# Out:
# The r-value is: -0.8958695384735601

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Set up the linear regression
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(38, 105)
plt.xlim(-60, 5)

plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
# Out:
# The r-value is: 0.6983919317936772

# %%
print("The linear regression is modeling where the average of the plots will fall down. For the Max Temp vs. Latitude scatter plot, it shows there is a negative correlation in the Northern Hemisphere while there is a positive correlation in the Southern Hemisphere.")
# Out:
# The linear regression is modeling where the average of the plots will fall down. For the Max Temp vs. Latitude scatter plot, it shows there is a negative correlation in the Northern Hemisphere while there is a positive correlation in the Southern Hemisphere.

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Set up the linear regression
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(0, 110)
plt.xlim(0, 80)

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-value is: 0.1902503157052442

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Set up the linear regression
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(0, 105)
plt.xlim(-54, 0)

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()
# Out:
# The r-value is: 0.017228887628552642

# %%
print("The linear regression is modeling where the average of the plots will fall down. For the Humidity vs Latitude scatter plot, it shows there is a positive correlation in the Nothern Hemisphere while there is a slight negative correlation in the Southern Hemisphere.")
# Out:
# The linear regression is modeling where the average of the plots will fall down. For the Humidity vs Latitude scatter plot, it shows there is a positive correlation in the Nothern Hemisphere while there is a slight negative correlation in the Southern Hemisphere.

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Set up the linear regression
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(-3, 102)
plt.xlim(-1, 80)

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-value is: 0.1477712390952331

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Set up the linear regression
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,15), fontsize=15,color="red")

plt.ylim(-3, 103)
plt.xlim(-54, 0)

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
# Out:
# The r-value is: 0.04081177191752812

# %%
print("The linear regression is modeling where the average of the plots will fall down. For the Cloudiness vs Latitude scatter plot, there is a positive correlation in the Northern Hemisphere while in the Southern Hemisphere the correlation falls down close to zero.")
# Out:
# The linear regression is modeling where the average of the plots will fall down. For the Cloudiness vs Latitude scatter plot, there is a positive correlation in the Northern Hemisphere while in the Southern Hemisphere the correlation falls down close to zero.

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Set up the linear regression
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,25), fontsize=15,color="red")

plt.ylim(-1, 35)
plt.xlim(-1, 80)

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-value is: 0.23490355917460046

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Set up the linear regression
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,6), fontsize=15,color="red")

plt.ylim(0, 25)
plt.xlim(-54, 0)

plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
# Out:
# The r-value is: -0.07822913722893705

# %%
print("The linear regression is modeling where the average of the plots will fall down. For the Wind Speed vs Latitude, there is small positive correlation in the Northern Hemisphere while there is a small negative correlation in the Southern Hemisphere.")
# Out:
# The linear regression is modeling where the average of the plots will fall down. For the Wind Speed vs Latitude, there is small positive correlation in the Northern Hemisphere while there is a small negative correlation in the Southern Hemisphere.
