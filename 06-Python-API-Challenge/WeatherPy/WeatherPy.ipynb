# %%
import matplotlib.pyplot as plt
import pandas as pd
from config import api_key
import random
import csv
import time
import requests

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'C:\Users\edwin\anaconda3\envs\PythonData\python.exe -m pip install --upgrade pip' command.

# %%
from citipy import citipy

# %%
cities = []

while len(cities)<643:

    x = (random.choice(range(-90, 90)))
    y = (random.choice(range(-180,180)))
    city = citipy.nearest_city(x,y).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 643

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


count = 1
sets = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    if count > 50:
        sets += 1
        count = 0
        
    print(f'Processing Record %s of Set %s | %s' % (count, sets, city))
    
    count += 1
    
    try:
        
        response = requests.get(f"{url}&q={city}").json()
        
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
         
    except:
        print("City not found. Skipping...")
    continue
    
print(f"--------------")
print(f"Data Retrieval Complete")
print(f"--------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | pangkalanbuun
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | soyo
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | kuala kedah
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | vardo
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | evensk
# Processing Record 18 of Set 1 | aksaray
# Processing Record 19 of Set 1 | karratha
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | talaya
# Processing Record 24 of Set 1 | kangaatsiaq
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | kibala
# Processing Record 27 of Set 1 | andra
# Processing Record 28 of Set 1 | conakry
# Processing Record 29 of Set 1 | owensboro
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | fortuna
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | mulchen
# Processing Record 35 of Set 1 | pietarsaari
# Processing Record 36 of Set 1 | coquimbo
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | laramie
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | holme
# Processing Record 42 of Set 1 | rapid valley
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | saint-francois
# Processing Record 47 of Set 1 | marathon
# Processing Record 48 of Set 1 | yelizovo
# Processing Record 49 of Set 1 | lake charles
# Processing Record 50 of Set 1 | caravelas
# Processing Record 0 of Set 2 | pishin
# Processing Record 1 of Set 2 | collie
# Processing Record 2 of Set 2 | loandjili
# Processing Record 3 of Set 2 | avera
# Processing Record 4 of Set 2 | aleksandrov gay
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | pisco
# Processing Record 7 of Set 2 | lokosovo
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | kutum
# Processing Record 13 of Set 2 | danilovka
# Processing Record 14 of Set 2 | sao joao da barra
# Processing Record 15 of Set 2 | edd
# Processing Record 16 of Set 2 | yankton
# Processing Record 17 of Set 2 | quang ngai
# Processing Record 18 of Set 2 | poddorye
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | sendafa
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | paamiut
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | acapulco
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | bengkulu
# Processing Record 30 of Set 2 | ligayan
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | riyadh
# Processing Record 34 of Set 2 | marawi
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | havoysund
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | tagusao
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | puerto colombia
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | hay river
# Processing Record 45 of Set 2 | ilinskiy
# Processing Record 46 of Set 2 | gobabis
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | torrington
# Processing Record 49 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 2 | svetlogorsk
# Processing Record 0 of Set 3 | ponta do sol
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | atambua
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | kragujevac
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | kouroussa
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | nyurba
# Processing Record 10 of Set 3 | canon city
# Processing Record 11 of Set 3 | saint george
# Processing Record 12 of Set 3 | manokwari
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | hambantota
# Processing Record 15 of Set 3 | pevek
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | safranbolu
# Processing Record 18 of Set 3 | saint-augustin
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | guerrero negro
# Processing Record 21 of Set 3 | asfi
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | sandwick
# Processing Record 24 of Set 3 | altamont
# Processing Record 25 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 3 | berbera
# Processing Record 27 of Set 3 | mlowo
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | palmer
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | ternate
# Processing Record 32 of Set 3 | irbit
# Processing Record 33 of Set 3 | tual
# Processing Record 34 of Set 3 | jalu
# Processing Record 35 of Set 3 | yulara
# Processing Record 36 of Set 3 | khasan
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | makasar
# Processing Record 39 of Set 3 | gondal
# Processing Record 40 of Set 3 | saint-joseph
# Processing Record 41 of Set 3 | antofagasta
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | niigata
# Processing Record 45 of Set 3 | salalah
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | isilkul
# Processing Record 50 of Set 3 | tonstad
# Processing Record 0 of Set 4 | tura
# Processing Record 1 of Set 4 | zlatarica
# City not found. Skipping...
# Processing Record 2 of Set 4 | baie-comeau
# Processing Record 3 of Set 4 | cape town
# Processing Record 4 of Set 4 | saldanha
# Processing Record 5 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 6 of Set 4 | margate
# Processing Record 7 of Set 4 | kluczbork
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | cachoeira do sul
# Processing Record 10 of Set 4 | tingo maria
# Processing Record 11 of Set 4 | chapais
# Processing Record 12 of Set 4 | yefremov
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | naze
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 4 | port hedland
# Processing Record 18 of Set 4 | kabalo
# Processing Record 19 of Set 4 | araouane
# Processing Record 20 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 4 | aswan
# Processing Record 22 of Set 4 | atar
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | menongue
# Processing Record 28 of Set 4 | pingxiang
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | kota tinggi
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | port macquarie
# Processing Record 33 of Set 4 | arlit
# Processing Record 34 of Set 4 | brae
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | iqaluit
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | ardahan
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | la tuque
# Processing Record 41 of Set 4 | kalmunai
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | goderich
# Processing Record 45 of Set 4 | sivas
# Processing Record 46 of Set 4 | grand gaube
# Processing Record 47 of Set 4 | solnechnyy
# Processing Record 48 of Set 4 | guanica
# Processing Record 49 of Set 4 | juneau
# Processing Record 50 of Set 4 | gazojak
# Processing Record 0 of Set 5 | kahului
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | vestmannaeyjar
# Processing Record 3 of Set 5 | nelson bay
# Processing Record 4 of Set 5 | shirokiy
# Processing Record 5 of Set 5 | quelimane
# Processing Record 6 of Set 5 | tambopata
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | teluk intan
# Processing Record 9 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | sioux lookout
# Processing Record 13 of Set 5 | ulaangom
# Processing Record 14 of Set 5 | jiwani
# Processing Record 15 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 5 | monrovia
# Processing Record 17 of Set 5 | bentiu
# Processing Record 18 of Set 5 | teguldet
# Processing Record 19 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | okandja
# City not found. Skipping...
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | sangar
# Processing Record 24 of Set 5 | bubaque
# Processing Record 25 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 5 | nosy varika
# Processing Record 27 of Set 5 | lovozero
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | amga
# Processing Record 30 of Set 5 | san jose
# Processing Record 31 of Set 5 | yeppoon
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | muscatine
# Processing Record 34 of Set 5 | camana
# Processing Record 35 of Set 5 | lamovita
# Processing Record 36 of Set 5 | maniitsoq
# Processing Record 37 of Set 5 | leningradskiy
# Processing Record 38 of Set 5 | carutapera
# Processing Record 39 of Set 5 | berlevag
# Processing Record 40 of Set 5 | cabadiangan
# Processing Record 41 of Set 5 | rehoboth
# Processing Record 42 of Set 5 | anadyr
# Processing Record 43 of Set 5 | constantine
# Processing Record 44 of Set 5 | safford
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | zhangye
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | crateus
# Processing Record 50 of Set 5 | katete
# Processing Record 0 of Set 6 | nalut
# Processing Record 1 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 6 | bihoro
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | puerto rondon
# Processing Record 5 of Set 6 | cochrane
# Processing Record 6 of Set 6 | oros
# Processing Record 7 of Set 6 | elizabeth city
# Processing Record 8 of Set 6 | sakaiminato
# Processing Record 9 of Set 6 | dawei
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | tornio
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | fort saint james
# Processing Record 14 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 6 | kautokeino
# Processing Record 16 of Set 6 | vostok
# Processing Record 17 of Set 6 | esna
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 6 | ponta delgada
# Processing Record 22 of Set 6 | bure
# Processing Record 23 of Set 6 | nadvoitsy
# Processing Record 24 of Set 6 | sur
# Processing Record 25 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | umm lajj
# Processing Record 28 of Set 6 | omboue
# Processing Record 29 of Set 6 | ormstown
# Processing Record 30 of Set 6 | sinnamary
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | ballitoville
# Processing Record 33 of Set 6 | delvine
# Processing Record 34 of Set 6 | la palma
# Processing Record 35 of Set 6 | george town
# Processing Record 36 of Set 6 | morag
# Processing Record 37 of Set 6 | krasnoyarsk
# Processing Record 38 of Set 6 | kawambwa
# Processing Record 39 of Set 6 | dali
# Processing Record 40 of Set 6 | calmar
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | cherskiy
# Processing Record 43 of Set 6 | denpasar
# Processing Record 44 of Set 6 | gwadar
# Processing Record 45 of Set 6 | akureyri
# Processing Record 46 of Set 6 | igrim
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | toamasina
# Processing Record 49 of Set 6 | aklavik
# Processing Record 50 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 0 of Set 7 | zhangjiakou
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 7 | kimbe
# Processing Record 4 of Set 7 | gigmoto
# Processing Record 5 of Set 7 | barpeta
# Processing Record 6 of Set 7 | wahpeton
# Processing Record 7 of Set 7 | yaan
# Processing Record 8 of Set 7 | kargasok
# Processing Record 9 of Set 7 | honningsvag
# Processing Record 10 of Set 7 | russkaya polyana
# Processing Record 11 of Set 7 | kaeo
# Processing Record 12 of Set 7 | bilma
# Processing Record 13 of Set 7 | puerto penasco
# Processing Record 14 of Set 7 | flinders
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | samarai
# Processing Record 17 of Set 7 | agadir
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | meulaboh
# Processing Record 20 of Set 7 | luganville
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | longyearbyen
# Processing Record 25 of Set 7 | camacha
# Processing Record 26 of Set 7 | mount hagen
# Processing Record 27 of Set 7 | kudahuvadhoo
# Processing Record 28 of Set 7 | jacqueville
# Processing Record 29 of Set 7 | cutro
# Processing Record 30 of Set 7 | ballina
# Processing Record 31 of Set 7 | inhambane
# Processing Record 32 of Set 7 | paris
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | mnogovershinnyy
# Processing Record 35 of Set 7 | saint-georges
# Processing Record 36 of Set 7 | spearfish
# Processing Record 37 of Set 7 | sobolevo
# Processing Record 38 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | constitucion
# Processing Record 40 of Set 7 | erenhot
# Processing Record 41 of Set 7 | bedford
# Processing Record 42 of Set 7 | robertson
# Processing Record 43 of Set 7 | lahaina
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | umarizal
# Processing Record 47 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 7 | springbok
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | superior
# Processing Record 0 of Set 8 | banda aceh
# Processing Record 1 of Set 8 | batemans bay
# Processing Record 2 of Set 8 | palasa
# Processing Record 3 of Set 8 | pontianak
# Processing Record 4 of Set 8 | sao felix do xingu
# Processing Record 5 of Set 8 | port hardy
# Processing Record 6 of Set 8 | okha
# Processing Record 7 of Set 8 | layton
# Processing Record 8 of Set 8 | batouri
# Processing Record 9 of Set 8 | plastun
# Processing Record 10 of Set 8 | kapuskasing
# Processing Record 11 of Set 8 | xichang
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | geraldton
# Processing Record 14 of Set 8 | koumac
# Processing Record 15 of Set 8 | aktash
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | puerto madryn
# Processing Record 18 of Set 8 | raga
# Processing Record 19 of Set 8 | vila velha
# Processing Record 20 of Set 8 | northam
# Processing Record 21 of Set 8 | celestun
# Processing Record 22 of Set 8 | kawardha
# Processing Record 23 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 8 | dodge city
# Processing Record 25 of Set 8 | quatre cocos
# Processing Record 26 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 8 | altay
# Processing Record 28 of Set 8 | belem de sao francisco
# Processing Record 29 of Set 8 | corinto
# Processing Record 30 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 8 | oussouye
# Processing Record 32 of Set 8 | grand forks
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | sorland
# Processing Record 35 of Set 8 | ondjiva
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | chara
# Processing Record 38 of Set 8 | estelle
# Processing Record 39 of Set 8 | acajutla
# Processing Record 40 of Set 8 | santa marta
# Processing Record 41 of Set 8 | touzim
# Processing Record 42 of Set 8 | amalner
# Processing Record 43 of Set 8 | zilair
# Processing Record 44 of Set 8 | boysun
# Processing Record 45 of Set 8 | gorontalo
# Processing Record 46 of Set 8 | mangan
# Processing Record 47 of Set 8 | forest acres
# Processing Record 48 of Set 8 | cartagena del chaira
# Processing Record 49 of Set 8 | codrington
# Processing Record 50 of Set 8 | birjand
# Processing Record 0 of Set 9 | te anau
# Processing Record 1 of Set 9 | jaen
# Processing Record 2 of Set 9 | kuytun
# Processing Record 3 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 9 | kifri
# Processing Record 6 of Set 9 | roma
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | axim
# Processing Record 9 of Set 9 | palana
# Processing Record 10 of Set 9 | makakilo city
# Processing Record 11 of Set 9 | tsuyama
# Processing Record 12 of Set 9 | oktyabrskiy
# Processing Record 13 of Set 9 | chitrakonda
# Processing Record 14 of Set 9 | mahibadhoo
# Processing Record 15 of Set 9 | picton
# Processing Record 16 of Set 9 | bay city
# Processing Record 17 of Set 9 | chase
# Processing Record 18 of Set 9 | zhuzhou
# Processing Record 19 of Set 9 | tateyama
# Processing Record 20 of Set 9 | mabaruma
# Processing Record 21 of Set 9 | moron
# Processing Record 22 of Set 9 | byron bay
# Processing Record 23 of Set 9 | ilo
# Processing Record 24 of Set 9 | muslyumovo
# Processing Record 25 of Set 9 | puerto del rosario
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | umm bab
# Processing Record 28 of Set 9 | tezu
# Processing Record 29 of Set 9 | burnie
# Processing Record 30 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 9 | tomatlan
# Processing Record 32 of Set 9 | piacabucu
# Processing Record 33 of Set 9 | nanakuli
# Processing Record 34 of Set 9 | keflavik
# Processing Record 35 of Set 9 | port-gentil
# Processing Record 36 of Set 9 | matto
# City not found. Skipping...
# Processing Record 37 of Set 9 | salinopolis
# Processing Record 38 of Set 9 | college
# Processing Record 39 of Set 9 | kagadi
# Processing Record 40 of Set 9 | vaasa
# Processing Record 41 of Set 9 | punta gorda
# Processing Record 42 of Set 9 | yatou
# Processing Record 43 of Set 9 | cururupu
# Processing Record 44 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 9 | sovetskiy
# Processing Record 46 of Set 9 | portmore
# Processing Record 47 of Set 9 | fort nelson
# Processing Record 48 of Set 9 | ambon
# Processing Record 49 of Set 9 | marsh harbour
# Processing Record 50 of Set 9 | antalaha
# Processing Record 0 of Set 10 | pringsewu
# Processing Record 1 of Set 10 | koungou
# Processing Record 2 of Set 10 | korla
# Processing Record 3 of Set 10 | erzurum
# Processing Record 4 of Set 10 | tapejara
# Processing Record 5 of Set 10 | preobrazheniye
# Processing Record 6 of Set 10 | batticaloa
# Processing Record 7 of Set 10 | lompoc
# Processing Record 8 of Set 10 | kidal
# Processing Record 9 of Set 10 | vitim
# Processing Record 10 of Set 10 | karasjok
# Processing Record 11 of Set 10 | basco
# Processing Record 12 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 13 of Set 10 | beruwala
# Processing Record 14 of Set 10 | tonk
# Processing Record 15 of Set 10 | ambunti
# Processing Record 16 of Set 10 | tuzla
# Processing Record 17 of Set 10 | almaznyy
# Processing Record 18 of Set 10 | san quintin
# Processing Record 19 of Set 10 | varhaug
# Processing Record 20 of Set 10 | pavlodar
# Processing Record 21 of Set 10 | shizunai
# Processing Record 22 of Set 10 | talnakh
# Processing Record 23 of Set 10 | iskateley
# Processing Record 24 of Set 10 | yerbogachen
# Processing Record 25 of Set 10 | ambanja
# Processing Record 26 of Set 10 | la trinitaria
# Processing Record 27 of Set 10 | guaymas
# Processing Record 28 of Set 10 | barkhan
# Processing Record 29 of Set 10 | huangnihe
# Processing Record 30 of Set 10 | huarmey
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | hofn
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | lukaya
# Processing Record 35 of Set 10 | nantucket
# Processing Record 36 of Set 10 | karasuk
# Processing Record 37 of Set 10 | albion
# Processing Record 38 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 10 | copiapo
# Processing Record 40 of Set 10 | limbang
# Processing Record 41 of Set 10 | bodden town
# Processing Record 42 of Set 10 | turukhansk
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | saint-paul
# Processing Record 45 of Set 10 | mailsi
# Processing Record 46 of Set 10 | carauari
# Processing Record 47 of Set 10 | rancho palos verdes
# Processing Record 48 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 10 | rio gallegos
# Processing Record 50 of Set 10 | mazagao
# Processing Record 0 of Set 11 | bhag
# Processing Record 1 of Set 11 | harper
# Processing Record 2 of Set 11 | talara
# Processing Record 3 of Set 11 | bilibino
# Processing Record 4 of Set 11 | tabuk
# Processing Record 5 of Set 11 | morant bay
# Processing Record 6 of Set 11 | baykit
# Processing Record 7 of Set 11 | alta floresta
# Processing Record 8 of Set 11 | srednekolymsk
# Processing Record 9 of Set 11 | lucapa
# Processing Record 10 of Set 11 | fare
# Processing Record 11 of Set 11 | butajira
# Processing Record 12 of Set 11 | benjamin hill
# Processing Record 13 of Set 11 | nalgonda
# Processing Record 14 of Set 11 | saint anthony
# Processing Record 15 of Set 11 | kearney
# Processing Record 16 of Set 11 | urengoy
# Processing Record 17 of Set 11 | chocaman
# Processing Record 18 of Set 11 | lang suan
# Processing Record 19 of Set 11 | melville
# Processing Record 20 of Set 11 | san onofre
# Processing Record 21 of Set 11 | marzuq
# Processing Record 22 of Set 11 | saiki
# Processing Record 23 of Set 11 | gat
# Processing Record 24 of Set 11 | dongli
# Processing Record 25 of Set 11 | namibe
# Processing Record 26 of Set 11 | katsuura
# Processing Record 27 of Set 11 | tilichiki
# Processing Record 28 of Set 11 | tabou
# Processing Record 29 of Set 11 | terrace bay
# Processing Record 30 of Set 11 | bay roberts
# Processing Record 31 of Set 11 | richards bay
# Processing Record 32 of Set 11 | westport
# Processing Record 33 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 11 | otradnoye
# Processing Record 35 of Set 11 | marystown
# Processing Record 36 of Set 11 | clearwater
# Processing Record 37 of Set 11 | winslow
# Processing Record 38 of Set 11 | atherton
# Processing Record 39 of Set 11 | vicente guerrero
# Processing Record 40 of Set 11 | mercedes
# Processing Record 41 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 11 | shchors
# Processing Record 43 of Set 11 | chuy
# Processing Record 44 of Set 11 | mahajanga
# Processing Record 45 of Set 11 | cabedelo
# Processing Record 46 of Set 11 | arroyo
# Processing Record 47 of Set 11 | qena
# Processing Record 48 of Set 11 | sonepur
# Processing Record 49 of Set 11 | beringovskiy
# Processing Record 50 of Set 11 | egvekinot
# Processing Record 0 of Set 12 | poum
# Processing Record 1 of Set 12 | lagunas
# Processing Record 2 of Set 12 | lakes entrance
# Processing Record 3 of Set 12 | darnah
# Processing Record 4 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 12 | namatanai
# Processing Record 6 of Set 12 | tsogni
# Processing Record 7 of Set 12 | eureka
# Processing Record 8 of Set 12 | nioro
# Processing Record 9 of Set 12 | salym
# Processing Record 10 of Set 12 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 11 of Set 12 | sakakah
# Processing Record 12 of Set 12 | tiarei
# Processing Record 13 of Set 12 | lima
# Processing Record 14 of Set 12 | uspenka
# Processing Record 15 of Set 12 | bhandara
# Processing Record 16 of Set 12 | panzhihua
# Processing Record 17 of Set 12 | freeport
# Processing Record 18 of Set 12 | wamba
# Processing Record 19 of Set 12 | nizwa
# Processing Record 20 of Set 12 | phek
# Processing Record 21 of Set 12 | san martin
# Processing Record 22 of Set 12 | gillette
# Processing Record 23 of Set 12 | paoua
# Processing Record 24 of Set 12 | kitimat
# Processing Record 25 of Set 12 | linguere
# Processing Record 26 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 12 | awjilah
# Processing Record 28 of Set 12 | ucluelet
# Processing Record 29 of Set 12 | champerico
# Processing Record 30 of Set 12 | kajaani
# Processing Record 31 of Set 12 | suntar
# Processing Record 32 of Set 12 | labytnangi
# Processing Record 33 of Set 12 | kuusamo
# Processing Record 34 of Set 12 | fort wellington
# Processing Record 35 of Set 12 | tadine
# Processing Record 36 of Set 12 | mastic beach
# Processing Record 37 of Set 12 | mahon
# Processing Record 38 of Set 12 | gorele
# Processing Record 39 of Set 12 | maceio
# Processing Record 40 of Set 12 | irece
# Processing Record 41 of Set 12 | coahuayana
# Processing Record 42 of Set 12 | coos bay
# Processing Record 43 of Set 12 | olinda
# Processing Record 44 of Set 12 | iranshahr
# Processing Record 45 of Set 12 | tooele
# Processing Record 46 of Set 12 | dakar
# Processing Record 47 of Set 12 | nome
# Processing Record 48 of Set 12 | barcelos
# Processing Record 49 of Set 12 | paka
# Processing Record 50 of Set 12 | fuerte olimpo
# Processing Record 0 of Set 13 | dingzhou
# Processing Record 1 of Set 13 | penzance
# Processing Record 2 of Set 13 | waingapu
# Processing Record 3 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | zaton
# Processing Record 6 of Set 13 | athabasca
# Processing Record 7 of Set 13 | zaysan
# Processing Record 8 of Set 13 | makokou
# Processing Record 9 of Set 13 | leczyca
# Processing Record 10 of Set 13 | treinta y tres
# Processing Record 11 of Set 13 | peleduy
# Processing Record 12 of Set 13 | sambava
# Processing Record 13 of Set 13 | bucyrus
# Processing Record 14 of Set 13 | serebryansk
# Processing Record 15 of Set 13 | filadelfia
# Processing Record 16 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 13 | pueblo nuevo
# Processing Record 18 of Set 13 | kloulklubed
# Processing Record 19 of Set 13 | ugoofaaru
# Processing Record 20 of Set 13 | benicarlo
# Processing Record 21 of Set 13 | asau
# Processing Record 22 of Set 13 | gaillac
# Processing Record 23 of Set 13 | uba
# Processing Record 24 of Set 13 | laguna
# Processing Record 25 of Set 13 | macamic
# Processing Record 26 of Set 13 | kambove
# Processing Record 27 of Set 13 | viseu
# Processing Record 28 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 13 | verkhnyaya sinyachikha
# Processing Record 30 of Set 13 | moindou
# Processing Record 31 of Set 13 | imperial
# --------------
# Data Retrieval Complete
# --------------

# %%
weather_dictionary = {
            "City": city_name,
            "Lat": lat,
            "Lng": lng,
            "Max Temp": max_temp,
            "Humidity": humidity,
            "Cloudiness": cloudiness,
            "Wind Speed": wind_speed,
            "Country": country,
            "Date": date,
}

weather_city_data = pd.DataFrame(weather_dictionary)

weather_city_data.to_csv('CSV Data/weather_city_data.csv',index=False)

weather_city_data.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
weather_city_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Rikitea -23.12 -134.97     74.97        80         100       20.31
# 1         Dikson  73.51   80.55     27.16        89          99       29.97
# 2     Bredasdorp -34.53   20.04     60.80        77         100        4.70
# 3  Pangkalanbuun  -2.68  111.62     73.58        97         100        2.57
# 4           Soyo  -6.13   12.37     77.81        84          97       11.63
#
#   Country        Date
# 0      PF  1603047740
# 1      RU  1603047745
# 2      ZA  1603047738
# 3      ID  1603047868
# 4      AO  1603047817

# %%
indexNames = weather_city_data[weather_city_data['Humidity'] > 100].index

weather_city_data.drop(indexNames, inplace = True)

weather_city_data.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Latitude vs Temperature Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Max Temp'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Temperature Plot.png")
plt.show()

# %%
# Latitude vs Humidity Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Humidity'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Humidity Plot.png")
plt.show()

# %%
# Latitude vs Cloudiness Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Cloudiness'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Cloudiness Plot.png")
plt.show()

# %%
# Latitude vs Wind Speed Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Wind Speed'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Wind Speed Plot.png")
plt.show()
