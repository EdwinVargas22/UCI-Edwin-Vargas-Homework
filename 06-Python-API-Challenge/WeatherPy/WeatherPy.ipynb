# %%
import matplotlib.pyplot as plt
import pandas as pd
from config import api_key
import random
import csv
import time
import requests
import scipy.stats as st

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\edwin\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'C:\Users\edwin\anaconda3\envs\PythonData\python.exe -m pip install --upgrade pip' command.

# %%
from citipy import citipy

# %%
cities = []

while len(cities)<643:

    x = (random.choice(range(-90, 90)))
    y = (random.choice(range(-180,180)))
    city = citipy.nearest_city(x,y).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 643

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []


count = 1
sets = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    if count > 50:
        sets += 1
        count = 0
        
    print(f'Processing Record %s of Set %s | %s' % (count, sets, city))
    
    count += 1
    
    try:
        
        response = requests.get(f"{url}&q={city}").json()
        
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
         
    except:
        print("City not found. Skipping...")
    continue
    
print(f"--------------")
print(f"Data Retrieval Complete")
print(f"--------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sampit
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | svetlyy
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | naze
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | bilma
# Processing Record 8 of Set 1 | policoro
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | saint-francois
# Processing Record 11 of Set 1 | tenno
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | zabaykalsk
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | namatanai
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | high rock
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | acapulco
# Processing Record 26 of Set 1 | kavaratti
# Processing Record 27 of Set 1 | port blair
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | kousseri
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | san pedro
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | bathsheba
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | klyuchi
# Processing Record 46 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 47 of Set 1 | bilibino
# Processing Record 48 of Set 1 | vieques
# Processing Record 49 of Set 1 | gushikawa
# Processing Record 50 of Set 1 | itoman
# Processing Record 0 of Set 2 | castro
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | tazovskiy
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | montale
# Processing Record 7 of Set 2 | jackson
# Processing Record 8 of Set 2 | barillas
# Processing Record 9 of Set 2 | bonthe
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | kulhudhuffushi
# Processing Record 12 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | velyka mykhaylivka
# Processing Record 14 of Set 2 | san patricio
# Processing Record 15 of Set 2 | smithers
# Processing Record 16 of Set 2 | honiara
# Processing Record 17 of Set 2 | oleksandrivka
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | yar-sale
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | jimenez
# Processing Record 22 of Set 2 | muravlenko
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | pangody
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | vaitape
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | bodmin
# Processing Record 34 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 2 | itupiranga
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | caravelas
# Processing Record 39 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | cherdyn
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | coihaique
# Processing Record 50 of Set 2 | kapaa
# Processing Record 0 of Set 3 | hithadhoo
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | flinders
# Processing Record 4 of Set 3 | tiksi
# Processing Record 5 of Set 3 | muroto
# Processing Record 6 of Set 3 | bela
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | kommunar
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | oistins
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | akdepe
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | parkes
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | de aar
# Processing Record 19 of Set 3 | meylan
# Processing Record 20 of Set 3 | atar
# Processing Record 21 of Set 3 | brigantine
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | pangnirtung
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | mehamn
# Processing Record 26 of Set 3 | calafat
# Processing Record 27 of Set 3 | ostashkov
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | nagato
# Processing Record 30 of Set 3 | turukhansk
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | cabra
# Processing Record 34 of Set 3 | teya
# Processing Record 35 of Set 3 | gofitskoye
# Processing Record 36 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 3 | ugoofaaru
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | mlowo
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | shenjiamen
# Processing Record 42 of Set 3 | migori
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | komsomolskiy
# Processing Record 45 of Set 3 | saint-joseph
# Processing Record 46 of Set 3 | pimentel
# Processing Record 47 of Set 3 | naranjal
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | butaritari
# Processing Record 0 of Set 4 | guozhen
# Processing Record 1 of Set 4 | sur
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | nizhniy kuranakh
# Processing Record 5 of Set 4 | te anau
# Processing Record 6 of Set 4 | lubango
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | mazara del vallo
# Processing Record 9 of Set 4 | salalah
# Processing Record 10 of Set 4 | ayame
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | new norfolk
# Processing Record 13 of Set 4 | champerico
# Processing Record 14 of Set 4 | berlevag
# Processing Record 15 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 4 | cap malheureux
# Processing Record 17 of Set 4 | teguise
# Processing Record 18 of Set 4 | sakakah
# Processing Record 19 of Set 4 | gromiljak
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | ulaanbaatar
# Processing Record 22 of Set 4 | banamba
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | sao miguel do araguaia
# Processing Record 25 of Set 4 | berdigestyakh
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | northam
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | merritt island
# Processing Record 30 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 4 | sao felix do xingu
# Processing Record 32 of Set 4 | yenagoa
# Processing Record 33 of Set 4 | kadiri
# Processing Record 34 of Set 4 | kinango
# Processing Record 35 of Set 4 | kenai
# Processing Record 36 of Set 4 | henties bay
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | katangli
# Processing Record 39 of Set 4 | ust-koksa
# Processing Record 40 of Set 4 | thinadhoo
# Processing Record 41 of Set 4 | ribeira grande
# Processing Record 42 of Set 4 | coruripe
# Processing Record 43 of Set 4 | pingzhuang
# Processing Record 44 of Set 4 | saint anthony
# Processing Record 45 of Set 4 | antri
# Processing Record 46 of Set 4 | alyangula
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | iznoski
# Processing Record 50 of Set 4 | avera
# Processing Record 0 of Set 5 | chumikan
# Processing Record 1 of Set 5 | gordeyevka
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | castro daire
# Processing Record 4 of Set 5 | hokitika
# Processing Record 5 of Set 5 | alta floresta
# Processing Record 6 of Set 5 | sawakin
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | hermiston
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 5 | sao joao da barra
# Processing Record 13 of Set 5 | deep river
# Processing Record 14 of Set 5 | fort nelson
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | axim
# Processing Record 17 of Set 5 | wote
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | mumbwa
# Processing Record 20 of Set 5 | mulege
# Processing Record 21 of Set 5 | chirongui
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | turka
# Processing Record 24 of Set 5 | mogwase
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | strezhevoy
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | biak
# Processing Record 29 of Set 5 | walvis bay
# Processing Record 30 of Set 5 | nyurba
# Processing Record 31 of Set 5 | georgiyevskoye
# Processing Record 32 of Set 5 | abu samrah
# Processing Record 33 of Set 5 | lazaro cardenas
# Processing Record 34 of Set 5 | nanortalik
# Processing Record 35 of Set 5 | adre
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | alice springs
# Processing Record 38 of Set 5 | honningsvag
# Processing Record 39 of Set 5 | bastia
# Processing Record 40 of Set 5 | palana
# Processing Record 41 of Set 5 | san juan
# Processing Record 42 of Set 5 | vitim
# Processing Record 43 of Set 5 | mao
# Processing Record 44 of Set 5 | nyakahanga
# Processing Record 45 of Set 5 | maragogi
# Processing Record 46 of Set 5 | creel
# Processing Record 47 of Set 5 | kandrian
# Processing Record 48 of Set 5 | faanui
# Processing Record 49 of Set 5 | saint-augustin
# Processing Record 50 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 0 of Set 6 | praia
# Processing Record 1 of Set 6 | portales
# Processing Record 2 of Set 6 | hami
# Processing Record 3 of Set 6 | irara
# Processing Record 4 of Set 6 | merced
# Processing Record 5 of Set 6 | linjiang
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | talcahuano
# Processing Record 8 of Set 6 | ivanovo
# Processing Record 9 of Set 6 | bonavista
# Processing Record 10 of Set 6 | kimbe
# Processing Record 11 of Set 6 | havre-saint-pierre
# Processing Record 12 of Set 6 | sinazongwe
# Processing Record 13 of Set 6 | ampanihy
# Processing Record 14 of Set 6 | noumea
# Processing Record 15 of Set 6 | isangel
# Processing Record 16 of Set 6 | mount isa
# Processing Record 17 of Set 6 | paracuru
# Processing Record 18 of Set 6 | yerbogachen
# Processing Record 19 of Set 6 | hay river
# Processing Record 20 of Set 6 | ikwiriri
# Processing Record 21 of Set 6 | phan thiet
# Processing Record 22 of Set 6 | vestmannaeyjar
# Processing Record 23 of Set 6 | guantanamo
# Processing Record 24 of Set 6 | zhigansk
# Processing Record 25 of Set 6 | acajutla
# Processing Record 26 of Set 6 | kumba
# Processing Record 27 of Set 6 | new smyrna beach
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | jalu
# Processing Record 30 of Set 6 | gigmoto
# Processing Record 31 of Set 6 | quesnel
# Processing Record 32 of Set 6 | egvekinot
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | polson
# Processing Record 35 of Set 6 | bambous virieux
# Processing Record 36 of Set 6 | omboue
# Processing Record 37 of Set 6 | gaspar
# Processing Record 38 of Set 6 | calvinia
# Processing Record 39 of Set 6 | omsukchan
# Processing Record 40 of Set 6 | esperance
# Processing Record 41 of Set 6 | de-kastri
# Processing Record 42 of Set 6 | devils lake
# Processing Record 43 of Set 6 | qaanaaq
# Processing Record 44 of Set 6 | airai
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | hervey bay
# Processing Record 47 of Set 6 | aklavik
# Processing Record 48 of Set 6 | margate
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | constitucion
# Processing Record 0 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 7 | pundaguitan
# Processing Record 2 of Set 7 | lompoc
# Processing Record 3 of Set 7 | ostrovnoy
# Processing Record 4 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | toledo
# Processing Record 7 of Set 7 | khandyga
# Processing Record 8 of Set 7 | sao gotardo
# Processing Record 9 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 7 | spas
# Processing Record 11 of Set 7 | edd
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | gardner
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | maniitsoq
# Processing Record 16 of Set 7 | ucluelet
# Processing Record 17 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 7 | ballitoville
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 7 | tessalit
# Processing Record 22 of Set 7 | lagoa
# Processing Record 23 of Set 7 | landsberg
# Processing Record 24 of Set 7 | rudnogorsk
# Processing Record 25 of Set 7 | aligarh
# Processing Record 26 of Set 7 | puerto leguizamo
# Processing Record 27 of Set 7 | manado
# Processing Record 28 of Set 7 | ostersund
# Processing Record 29 of Set 7 | launceston
# Processing Record 30 of Set 7 | praia da vitoria
# Processing Record 31 of Set 7 | mogadishu
# Processing Record 32 of Set 7 | gillette
# Processing Record 33 of Set 7 | mahalapye
# Processing Record 34 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 7 | arrecife
# Processing Record 36 of Set 7 | karratha
# Processing Record 37 of Set 7 | sedkyrkeshch
# Processing Record 38 of Set 7 | culebra
# Processing Record 39 of Set 7 | zalaszentgrot
# Processing Record 40 of Set 7 | kovylkino
# Processing Record 41 of Set 7 | san jose
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | saint-pierre
# Processing Record 45 of Set 7 | coahuayana
# Processing Record 46 of Set 7 | opuwo
# Processing Record 47 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | kloulklubed
# Processing Record 50 of Set 7 | corinto
# Processing Record 0 of Set 8 | hovd
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 8 | vila franca do campo
# Processing Record 4 of Set 8 | mackay
# Processing Record 5 of Set 8 | vao
# Processing Record 6 of Set 8 | abu kamal
# Processing Record 7 of Set 8 | inongo
# Processing Record 8 of Set 8 | sistranda
# Processing Record 9 of Set 8 | coos bay
# Processing Record 10 of Set 8 | dafeng
# Processing Record 11 of Set 8 | arona
# Processing Record 12 of Set 8 | muhos
# Processing Record 13 of Set 8 | boditi
# Processing Record 14 of Set 8 | hope mills
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | colon
# Processing Record 17 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 8 | bethanien
# Processing Record 19 of Set 8 | sayyan
# Processing Record 20 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 8 | luganville
# Processing Record 22 of Set 8 | gravdal
# Processing Record 23 of Set 8 | semey
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | baculin
# Processing Record 27 of Set 8 | souillac
# Processing Record 28 of Set 8 | kralendijk
# Processing Record 29 of Set 8 | arkhipo-osipovka
# Processing Record 30 of Set 8 | santa rosa
# Processing Record 31 of Set 8 | poum
# Processing Record 32 of Set 8 | ust-nera
# Processing Record 33 of Set 8 | biltine
# Processing Record 34 of Set 8 | college
# Processing Record 35 of Set 8 | midland
# Processing Record 36 of Set 8 | bagdarin
# Processing Record 37 of Set 8 | wabana
# Processing Record 38 of Set 8 | moree
# Processing Record 39 of Set 8 | qui nhon
# Processing Record 40 of Set 8 | thompson
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | ariquemes
# Processing Record 43 of Set 8 | fagernes
# Processing Record 44 of Set 8 | manzil salim
# Processing Record 45 of Set 8 | ahipara
# Processing Record 46 of Set 8 | salinopolis
# Processing Record 47 of Set 8 | elko
# Processing Record 48 of Set 8 | marau
# Processing Record 49 of Set 8 | izhma
# Processing Record 50 of Set 8 | abha
# Processing Record 0 of Set 9 | pinsk
# Processing Record 1 of Set 9 | mildura
# Processing Record 2 of Set 9 | bondowoso
# Processing Record 3 of Set 9 | pirna
# Processing Record 4 of Set 9 | laguna
# Processing Record 5 of Set 9 | caluquembe
# Processing Record 6 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 9 | tombouctou
# Processing Record 8 of Set 9 | halifax
# Processing Record 9 of Set 9 | khani
# Processing Record 10 of Set 9 | darhan
# Processing Record 11 of Set 9 | calgary
# Processing Record 12 of Set 9 | syasstroy
# Processing Record 13 of Set 9 | padang
# Processing Record 14 of Set 9 | exeter
# Processing Record 15 of Set 9 | sola
# Processing Record 16 of Set 9 | bartica
# Processing Record 17 of Set 9 | ballina
# Processing Record 18 of Set 9 | bandarbeyla
# Processing Record 19 of Set 9 | iquitos
# Processing Record 20 of Set 9 | cherskiy
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | beloha
# Processing Record 23 of Set 9 | awbari
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | huarmey
# Processing Record 26 of Set 9 | santa isabel do rio negro
# Processing Record 27 of Set 9 | puerto del rosario
# Processing Record 28 of Set 9 | colares
# Processing Record 29 of Set 9 | mamallapuram
# Processing Record 30 of Set 9 | kamenka
# Processing Record 31 of Set 9 | sibolga
# Processing Record 32 of Set 9 | linxia
# Processing Record 33 of Set 9 | atambua
# Processing Record 34 of Set 9 | barabai
# Processing Record 35 of Set 9 | ajaccio
# Processing Record 36 of Set 9 | ravar
# Processing Record 37 of Set 9 | castanheira de pera
# Processing Record 38 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 39 of Set 9 | chara
# Processing Record 40 of Set 9 | lugovoy
# Processing Record 41 of Set 9 | mayumba
# Processing Record 42 of Set 9 | iracoubo
# Processing Record 43 of Set 9 | vilyuysk
# Processing Record 44 of Set 9 | santarem
# Processing Record 45 of Set 9 | stupino
# Processing Record 46 of Set 9 | domoni
# Processing Record 47 of Set 9 | farrukhnagar
# Processing Record 48 of Set 9 | promakhoi
# City not found. Skipping...
# Processing Record 49 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 9 | bowmore
# Processing Record 0 of Set 10 | bud
# Processing Record 1 of Set 10 | odemis
# City not found. Skipping...
# Processing Record 2 of Set 10 | araouane
# Processing Record 3 of Set 10 | taoudenni
# Processing Record 4 of Set 10 | pitimbu
# Processing Record 5 of Set 10 | okha
# Processing Record 6 of Set 10 | kuala lipis
# Processing Record 7 of Set 10 | barranca
# Processing Record 8 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 10 | los andes
# Processing Record 10 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 10 | neftcala
# Processing Record 12 of Set 10 | tabas
# Processing Record 13 of Set 10 | cap-aux-meules
# Processing Record 14 of Set 10 | mumford
# Processing Record 15 of Set 10 | ulaangom
# Processing Record 16 of Set 10 | antalaha
# Processing Record 17 of Set 10 | bo phloi
# Processing Record 18 of Set 10 | hanover
# Processing Record 19 of Set 10 | nioro
# Processing Record 20 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 10 | kudahuvadhoo
# Processing Record 22 of Set 10 | porto belo
# Processing Record 23 of Set 10 | rocha
# Processing Record 24 of Set 10 | faya
# Processing Record 25 of Set 10 | leningradskiy
# Processing Record 26 of Set 10 | pandan
# Processing Record 27 of Set 10 | enkoping
# Processing Record 28 of Set 10 | mananara
# Processing Record 29 of Set 10 | tura
# Processing Record 30 of Set 10 | san quintin
# Processing Record 31 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 32 of Set 10 | gari
# Processing Record 33 of Set 10 | san andres
# Processing Record 34 of Set 10 | sicamous
# Processing Record 35 of Set 10 | gobabis
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | ternate
# Processing Record 38 of Set 10 | narsaq
# Processing Record 39 of Set 10 | filingue
# Processing Record 40 of Set 10 | addanki
# Processing Record 41 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 42 of Set 10 | mae hong son
# Processing Record 43 of Set 10 | ngunguru
# Processing Record 44 of Set 10 | yeppoon
# Processing Record 45 of Set 10 | ouro fino
# Processing Record 46 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 10 | poronaysk
# Processing Record 48 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 49 of Set 10 | tomatlan
# Processing Record 50 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 11 | road town
# Processing Record 1 of Set 11 | esmeraldas
# Processing Record 2 of Set 11 | lanivtsi
# Processing Record 3 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 4 of Set 11 | goksun
# Processing Record 5 of Set 11 | solnechnyy
# Processing Record 6 of Set 11 | viedma
# Processing Record 7 of Set 11 | trinidad
# Processing Record 8 of Set 11 | erie
# Processing Record 9 of Set 11 | talnakh
# Processing Record 10 of Set 11 | doha
# Processing Record 11 of Set 11 | daru
# Processing Record 12 of Set 11 | qasigiannguit
# Processing Record 13 of Set 11 | san ramon de la nueva oran
# Processing Record 14 of Set 11 | tocopilla
# Processing Record 15 of Set 11 | san joaquin
# Processing Record 16 of Set 11 | russell
# Processing Record 17 of Set 11 | siirt
# Processing Record 18 of Set 11 | mitsamiouli
# Processing Record 19 of Set 11 | chino valley
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | rundu
# Processing Record 22 of Set 11 | nortelandia
# Processing Record 23 of Set 11 | chernyshevskiy
# Processing Record 24 of Set 11 | asenovgrad
# Processing Record 25 of Set 11 | itapirapua
# Processing Record 26 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 11 | burnie
# Processing Record 28 of Set 11 | kiama
# Processing Record 29 of Set 11 | joshimath
# Processing Record 30 of Set 11 | nazarovo
# Processing Record 31 of Set 11 | rosendal
# Processing Record 32 of Set 11 | tucurui
# Processing Record 33 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 11 | shushenskoye
# Processing Record 37 of Set 11 | bara
# Processing Record 38 of Set 11 | hovorany
# Processing Record 39 of Set 11 | olafsvik
# Processing Record 40 of Set 11 | abramovka
# Processing Record 41 of Set 11 | gamboma
# Processing Record 42 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 11 | partyzany
# Processing Record 44 of Set 11 | kruisfontein
# Processing Record 45 of Set 11 | dubbo
# Processing Record 46 of Set 11 | new ulm
# Processing Record 47 of Set 11 | chodziez
# Processing Record 48 of Set 11 | moose factory
# Processing Record 49 of Set 11 | evreux
# Processing Record 50 of Set 11 | milkovo
# Processing Record 0 of Set 12 | leshukonskoye
# Processing Record 1 of Set 12 | osa
# Processing Record 2 of Set 12 | taonan
# Processing Record 3 of Set 12 | high level
# Processing Record 4 of Set 12 | kysyl-syr
# Processing Record 5 of Set 12 | fasa
# Processing Record 6 of Set 12 | dire dawa
# Processing Record 7 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 12 | goderich
# Processing Record 9 of Set 12 | ilula
# Processing Record 10 of Set 12 | alenquer
# Processing Record 11 of Set 12 | plouzane
# Processing Record 12 of Set 12 | kirkland lake
# Processing Record 13 of Set 12 | feijo
# Processing Record 14 of Set 12 | prachatice
# Processing Record 15 of Set 12 | massa marittima
# Processing Record 16 of Set 12 | quatre cocos
# Processing Record 17 of Set 12 | ust-kulom
# Processing Record 18 of Set 12 | aswan
# Processing Record 19 of Set 12 | guerrero negro
# Processing Record 20 of Set 12 | ilo
# Processing Record 21 of Set 12 | batagay-alyta
# Processing Record 22 of Set 12 | tongzi
# Processing Record 23 of Set 12 | durres
# Processing Record 24 of Set 12 | sabinas
# Processing Record 25 of Set 12 | jutai
# Processing Record 26 of Set 12 | banda aceh
# Processing Record 27 of Set 12 | korla
# Processing Record 28 of Set 12 | yumen
# Processing Record 29 of Set 12 | eydhafushi
# Processing Record 30 of Set 12 | dinghai
# Processing Record 31 of Set 12 | lucea
# Processing Record 32 of Set 12 | marzuq
# Processing Record 33 of Set 12 | bayburt
# Processing Record 34 of Set 12 | lima
# Processing Record 35 of Set 12 | north augusta
# Processing Record 36 of Set 12 | harper
# Processing Record 37 of Set 12 | lasa
# Processing Record 38 of Set 12 | morro da fumaca
# Processing Record 39 of Set 12 | byron bay
# Processing Record 40 of Set 12 | montepuez
# Processing Record 41 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 42 of Set 12 | manakara
# Processing Record 43 of Set 12 | darnah
# Processing Record 44 of Set 12 | katherine
# Processing Record 45 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 12 | maceio
# Processing Record 48 of Set 12 | pingliang
# Processing Record 49 of Set 12 | ambo
# Processing Record 50 of Set 12 | anloga
# Processing Record 0 of Set 13 | mgandu
# Processing Record 1 of Set 13 | vitre
# Processing Record 2 of Set 13 | swinford
# Processing Record 3 of Set 13 | vernon
# Processing Record 4 of Set 13 | helena
# Processing Record 5 of Set 13 | menomonie
# Processing Record 6 of Set 13 | sungai udang
# Processing Record 7 of Set 13 | chapais
# Processing Record 8 of Set 13 | kurumkan
# Processing Record 9 of Set 13 | tessaoua
# Processing Record 10 of Set 13 | rincon
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | wanlaweyn
# Processing Record 13 of Set 13 | rovenki
# Processing Record 14 of Set 13 | taltal
# Processing Record 15 of Set 13 | erenhot
# Processing Record 16 of Set 13 | kasempa
# Processing Record 17 of Set 13 | gilgit
# Processing Record 18 of Set 13 | kumla
# Processing Record 19 of Set 13 | waipawa
# Processing Record 20 of Set 13 | gaurnadi
# Processing Record 21 of Set 13 | fairbanks
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | dinar
# Processing Record 24 of Set 13 | jinchang
# Processing Record 25 of Set 13 | araxa
# Processing Record 26 of Set 13 | riyadh
# Processing Record 27 of Set 13 | adrar
# Processing Record 28 of Set 13 | vasilsursk
# Processing Record 29 of Set 13 | kapit
# Processing Record 30 of Set 13 | saint-louis
# Processing Record 31 of Set 13 | shchigry
# --------------
# Data Retrieval Complete
# --------------

# %%
weather_dictionary = {
            "City": city_name,
            "Lat": lat,
            "Lng": lng,
            "Max Temp": max_temp,
            "Humidity": humidity,
            "Cloudiness": cloudiness,
            "Wind Speed": wind_speed,
            "Country": country,
            "Date": date,
}

weather_city_data = pd.DataFrame(weather_dictionary)

weather_city_data.to_csv('CSV Data/weather_city_data.csv',index=False)

weather_city_data.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
weather_city_data.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Sampit  -2.53  112.95     73.06        98          99        2.35
# 1      Ushuaia -54.80  -68.30     41.00        80          75       29.97
# 2  Tsimmerbude  54.67   20.13     48.99        80          20        8.95
# 3    Cape Town -33.93   18.42     61.00        82          20       13.87
# 4         Naze  28.37  129.48     75.20        88          90       19.46
#
#   Country        Date
# 0      ID  1603052668
# 1      AR  1603052668
# 2      RU  1603052669
# 3      ZA  1603052580
# 4      JP  1603052669

# %%
indexNames = weather_city_data[weather_city_data['Humidity'] > 100].index

weather_city_data.drop(indexNames, inplace = True)

weather_city_data.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Latitude vs Temperature Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Max Temp'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Temperature Plot.png")
plt.show()

# %%
# Latitude vs Humidity Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Humidity'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Humidity Plot.png")
plt.show()

# %%
# Latitude vs Cloudiness Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Cloudiness'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Cloudiness Plot.png")
plt.show()

# %%
# Latitude vs Wind Speed Plot
plt.scatter(weather_city_data['Lat'], weather_city_data['Wind Speed'], edgecolor="black", marker="o")

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude vs. Wind Speed Plot.png")
plt.show()

# %%
northern_hemisphere = weather_city_data.loc[weather_city_data["Lat"] >= 0]
southern_hemisphere = weather_city_data.loc[weather_city_data["Lat"] < 0]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression  
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(0, 100)
plt.xlim(0, 80)

plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
# Out:
# The r-value is: -0.8777035326454932

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print(f"The r-value is: {rvalue}")
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot the scatter graph and linear regression
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50), fontsize=15,color="red")

plt.ylim(38, 105)
plt.xlim(-60, 5)

plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()
# Out:
# The r-value is: 0.6979148867760478
